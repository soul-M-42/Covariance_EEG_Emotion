# %%
data_dir_me = '/mnt/dataset0/qingzhu/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/patch_multi_f0_fea_epoch=19.ckptme.npy'
data_dir_de = '/mnt/dataset0/qingzhu/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/patch_multi_f0_fea_epoch=19.ckptde.npy'

# %%
import numpy as np
data_de = np.load(data_dir_de)
data_me = np.load(data_dir_me)

# %%
import numpy as np
data = np.load(data_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import numpy as np
# ----> 2 data = np.load(data_dir)
#
# NameError: name 'data_dir' is not defined

# %%
data.shape
# Out:
# (57616, 256)

# %%
import matplotlib.pyplot as plt

# %%
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()

# %%
show_data(data[:512])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 show_data(data[:512])
#
# NameError: name 'data' is not defined

# %%
import numpy as np
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = '/mnt/dataset0/qingzhu/workspace/Covariance_EEG_Emotion/visualize/features/SEEDV_DE/DE_NOLDS_NONORM.npy'
data = np.load(data_dir)
print(data.shape)
show_data(data[:512])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 data_dir = '/mnt/dataset0/qingzhu/workspace/Covariance_EEG_Emotion/visualize/features/SEEDV_DE/DE_NOLDS_NONORM.npy'
# ----> 2 data = np.load(data_dir)
#       3 print(data.shape)
#       4 show_data(data[:512])
#
# NameError: name 'np' is not defined

# %%
dir_old = '/mnt/dataset0/qingzhu/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/CNN_baseline_f0_fea_pretrain_me.npy'
data_old = np.load(dir_old)
print(data_old.shape)
show_data(data_old[:512])
# Out:
# (117744, 256)

# %%
dir_cnn_new = '/mnt/dataset0/qingzhu/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/CNN_bsl_f0_fea_epoch=19.ckptde.npy'
data_cnn_new = np.load(dir_cnn_new)
print(data_cnn_new.shape)
show_data(data_cnn_new[:512])
# Out:
# (117744, 256)

# %%
dir_mlla = '/mnt/dataset0/qingzhu/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/replace_align_f0_fea_DE.npy'
data_mlla = np.load(dir_mlla)
print(data_mlla.shape)
show_data(data_mlla[:512])
# Out:
# (117744, 300)

# %%
dir_determin = '/mnt/dataset0/qingzhu/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/cnnNormAfterMLP_f0_fea_epoch=19.ckptme.npy'
data_determin = np.load(dir_determin)
print(data_determin.shape)
show_data(data_determin[:512])
# Out:
# (57616, 256)

# %%
dir_determin = '/mnt/dataset0/qingzhu/AutoICA_Processed_EEG/SEED_V/Processed_data_filter_0.50_47.00_AutoICA_Def_Threshold/data_3in1/ext_fea/cnnNormAfterMLP_f0_fea_DE.npy'
data_determin = np.load(dir_determin)
print(data_determin.shape)
show_data(data_determin[:512])
# Out:
# (57616, 300)

# %%
import torch

# 创建随机 Tensor
tensor = torch.randn(30, 1, 60, 625, dtype=torch.float32, device="cuda")

# 查看内存占用
print(f"Tensor 内存占用: {tensor.element_size() * tensor.numel() / 1024**2:.2f} MB")
# Out:
# Tensor 内存占用: 4.29 MB

# %%
import numpy as np
import matplotlib.pyplot as plt 
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = './saved_data/beforeTSTencoder.npy'
data_show = np.load(data_dir)
print(data_show.shape)
show_data(data_show[8])
# Out:
# (64, 60, 625)

# %%
import numpy as np
import matplotlib.pyplot as plt 
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = './saved_data/afterTSTencoder.npy'
data_show = np.load(data_dir)
print(data_show.shape)
show_data(data_show.reshape((64, 60 * 16, 149))[8])
# Out:
# (64, 60, 16, 149)

# %%
import numpy as np
import matplotlib.pyplot as plt 
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
data_dir = './saved_data/afterTFencoder.npy'
data_show = np.load(data_dir)
print(data_show.shape)
show_data(data_show[8])
# Out:
# (64, 60, 149, 32)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 11
#       9 data_show = np.load(data_dir)
#      10 print(data_show.shape)
# ---> 11 show_data(data_show[8])
#
# Cell In[59], line 5, in show_data(data)
#       3 def show_data(data):
#       4     fig, ax = plt.subplots()
# ----> 5     cax = ax.imshow(data)
#       6     fig.colorbar(cax)
#       7     plt.show()
#
# File ~/miniconda3/envs/torch/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
# ...

# %%
show_data(data_show[8])

# %%
import numpy as np
data = np.load('./visualize/projected_eeg.npy')
data.shape
# Out:
# (30, 1, 94, 625)

# %%
data_trial = data[0][0]

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_multichannel_data(data, x=None, offset=None, spacing=3.0, 
                          channel_labels=None, cmap='viridis', ax=None, **kwargs):
    """
    绘制多通道时间序列数据，自动垂直偏移通道
    
    参数：
    data : ndarray, shape (n_channels, n_time)
        输入的多通道时间序列数据
    x : ndarray, shape (n_time,), optional
        时间轴数据，默认为 [0, 1, ..., n_time-1]
    offset : float, optional
        通道间垂直偏移量，自动计算时使用 spacing * max_amplitude
    spacing : float
        通道间距系数（当offset为None时生效）
    channel_labels : list of str, optional
        通道标签列表
    cmap : str
        颜色映射名称
    ax : matplotlib axis, optional
        指定绘图的axis对象
    **kwargs : 
        传递给plot函数的其他参数
    """
    # 验证输入数据维度
    if data.ndim != 2:
        raise ValueError("输入数据必须是二维数组 (n_channels, n_time)")
    
    n_channels, n_time = data.shape
    x = np.arange(n_time) if x is None else x
    
    # 自动计算垂直偏移量
    if offset is None:
        max_amp = np.max(np.abs(data))
        offset = max_amp * spacing
    
    # 创建颜色映射
    colors = plt.cm.get_cmap(cmap)(np.linspace(0, 1, n_channels))
    
    # 创建或获取axis对象
    ax = ax if ax is not None else plt.gca()
    
    # 绘制每个通道
    for i in range(n_channels):
        y_shifted = data[i] + i * offset
        ax.plot(x, y_shifted, color=colors[i], **kwargs)
    
    # 设置y轴标签
    yticks = [i * offset for i in range(n_channels)]
    yticklabels = channel_labels if channel_labels else [f'Channel {i}' for i in range(n_channels)]
    ax.set_yticks(yticks)
    ax.set_yticklabels(yticklabels)
    
    ax.set_xlabel('Time')
    return ax

plt.figure(figsize=(10, 6))
plot_multichannel_data(data_trial, spacing=0)
plt.title('Multichannel Biosignal Visualization')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1015830/3609673333.py:40: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap(cmap)(np.linspace(0, 1, n_channels))

# %%
import numpy as np
data = np.load('./visualize/data_before_project.npy')
data_show = data[0][0]
print(data_show.shape)
plt.figure(figsize=(10, 6))
plot_multichannel_data(data_show, spacing=0)
plt.title('Multichannel Biosignal Visualization')
plt.tight_layout()
plt.show()
# Out:
# (60, 625)
# /tmp/ipykernel_1015830/753895605.py:40: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap(cmap)(np.linspace(0, 1, n_channels))

# %%
pro_mat = np.load('./visualize/project_matrix.npy')
pro_mat.shape
# Out:
# (60, 94)

# %%
def show_data(data):
    fig, ax = plt.subplots()
    cax = ax.imshow(data)
    fig.colorbar(cax)
    plt.show()
pro_mat = np.load('./visualize/project_matrix.npy')
show_data(pro_mat)

# %%
# Out:
# (94, 61452)

# %%
import numpy as np
cha_weight_dir = '/mnt/dataset1/ws2319/workspace/ESI_pipelines/qingzhu/leadfield_fsaverage_standard_1020.npz'
leadfield = np.load(cha_weight_dir)['leadfield']

# %%
L = leadfield
print(L.shape)
C = np.eye(L.shape[0])
W = np.linalg.inv(L.T @ np.linalg.inv(C) @ L) @ L.T @ np.linalg.inv(C)
print(W.shape)
# Out:
# (61452, 94)
